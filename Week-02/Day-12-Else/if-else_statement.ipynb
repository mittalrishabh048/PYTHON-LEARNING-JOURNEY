# %% [markdown]
# <a href="https://colab.research.google.com/github/mittalrishabh048/PYTHON-LEARNING-JOURNEY/blob/main/Week-02/Day-12-Else/if-else_statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DAY 12:CONDITIONAL STATEMENTS:2."ELSE"
#
# *ELSE IS USED ONLY "ONE TIME" IN THE LAST OF PROGRAM AND WORKS ONLY WHEN ALL THE STATEMENTS ABOVE ARE FALSE.

# %%
age=21

if(age>=18):
  print("ELIGIBLE FOR VOTING.")
else:
  print("NOT ELIGIBLE.")

AGE=16

if(AGE>=18):
  print("ELIGIBLE FOR VOTING")
else:
  print
# Out:
# ELIGIBLE FOR VOTING.
