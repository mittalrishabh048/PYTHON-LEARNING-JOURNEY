# %% [markdown]
# <a href="https://colab.research.google.com/github/mittalrishabh048/PYTHON-LEARNING-JOURNEY/blob/main/Week-02/Day-13-Elif/Elif_statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DAY 13:CONDITIONAL STATEMENTS:"Elif"

# %%
light="green"
if(light=="red"):
  print("STOP.")
elif(light=="green"):
  print("GO.")
elif(light=="yellow"):
  print("LOOK.")

#WRITE A PROGRAM TO FIND THE GREATEST OF THREE NUMBERS ENTERED BY THE USER.
num1=int(input("ENTER NUM1:"))
num2=int(input("ENTER NUM2:"))
num3=int(input("ENTER NUM3:"))

if(num1>num2 and num1>num3):
  print("NUM1 IS GREATEST.")
elif(num2>num1 and num2>num3):
  print("NUM2 IS GREATEST.")
elif(num3>num1 and num3>num2):
  print("NUM3 IS GREATEST.")
# Out:
# GO.
