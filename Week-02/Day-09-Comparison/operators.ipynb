# %% [markdown]
# <a href="https://colab.research.google.com/github/mittalrishabh048/PYTHON-LEARNING-JOURNEY/blob/main/Week-02/Day-09-Comparison/operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DAY 9:COMPARISON/RELATIONAL OPERATORS(==,!=,<,>,<=,>=)

# %%
#THESE ALWAYS GIVES ANS IN "True" OR "False".
a=50
b=25
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)

c=25
d=25
print(c==d)
print(c<=d)
print(d<=c)
print(d>c",c>d)
# Out:
# False
# True
# True
# False
# True
# False
# True
# True
# True
# False False
