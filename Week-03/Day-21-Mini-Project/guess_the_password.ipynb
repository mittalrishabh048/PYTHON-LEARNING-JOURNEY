# %% [markdown]
# <a href="https://colab.research.google.com/github/mittalrishabh048/PYTHON-LEARNING-JOURNEY/blob/main/Week-03/Day-21-Mini-Project/guess_the_password.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DAY 21:REVISION(WEEK) AND MINI-PROJECT.

# %%
#MINI-PROJECT==>PASSWORD CRACKER GAME.
#PRACTICE:while,continue,break.
correct_pass="PASSWORD"
attempts=0
max_attempts=3
print("Guess the password(3 attempts max):")
while attempts<max_attempts:
  guess=input("ENTER THE PASSWORD:")
  attempts+=1

  if (guess==correct_pass):
    print("Access granted.")
    break
  else:
    print("Wrong Password!Try again.")
    if (attempts<max_attempts):
      continue
    print("Account Blocked!")
# Out:
# Guess the password(3 attempts max):
# ENTER THE PASSWORD:password
# Wrong Password!Try again.
# ENTER THE PASSWORD:Password
# Wrong Password!Try again.
# ENTER THE PASSWORD:PASSWORD
# Access granted.
