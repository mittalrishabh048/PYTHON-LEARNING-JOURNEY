# %% [markdown]
# <a href="https://colab.research.google.com/github/mittalrishabh048/PYTHON-LEARNING-JOURNEY/blob/main/Week-01/Day-03-Variables/variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DAY 3:VARIABLES(A VARIABLE IS A NAME GIVEN TO A MEMORY LOCATION IN A PROGRAM OR A CERTAIN VALUE IS STORED IN A PARTICULAR TYPE OF WORD"MEMORY")

# %%
name="rishabh"
age=17
price=10.99

age2=age

print(name,",",age,",",price)
print("My name is:",name)
print("My age is:", age)
print(age2)
# Out:
# rishabh , 17 , 10.99
# My name is: rishabh
# My age is: 17
# 17

# %%
#PRACTICE QUES:
a=6
b=4
sum=a+b
diff=a-b
multiply=a*b
print(sum)
print(diff)
print(multiply)
# Out:
# 10
# 2
# 24
