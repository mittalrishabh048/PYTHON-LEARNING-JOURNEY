# %% [markdown]
# <a href="https://colab.research.google.com/github/mittalrishabh048/PYTHON-LEARNING-JOURNEY/blob/main/Week-01/Day-05-UserInput/user_input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DAY 5:USER INPUT OR INPUT(FUNCTION)
#       *input()=result of every input is string.
#       To change its data type , we have to use type
#       casting that we will learn the next day.

# %%
input("enter your name:")
#1.
name=input("enter your name:")
print("welcome,",name)
#2.
value=input("enter some value:")
print("you entered:",value)
print(type(name))
print(type(value))
# Out:
# enter your name:rishabh
# enter your name:rishbh
# welcome, rishbh
# enter some value:23.44
# you entered: 23.44
# <class 'str'>
# <class 'str'>

# %%
#3.PRACTICE FOR THE DAY:
name=input("enter name:")
age=input("enter yoyr age:")
val=input("enter your value:")

print("welcome:",name)
print("your age is:",age)
print("you entered value:",val)
# Out:
# enter name:rishabh
# enter yoyr age:17
# enter your value:99
# welcome: rishabh
# your age is: 17
# you entered value: 99
