# %% [markdown]
# <a href="https://colab.research.google.com/github/mittalrishabh048/PYTHON-LEARNING-JOURNEY/blob/main/Week-01/Day-07-Project/greeting_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DAY 7:REVISIOM(WEAK) AND A GREETING PROGRAM (MINI-PROJECT)

# %%
name=input("enter your name:")
age=int(input("enter your age:"))
location=input("where are you from:")
A="THANKS FOR VISITING MY REPO,HAVE A NICE DAY."

print("Welcome,",name)
print("You are",age,"years old.")
print(A)
# Out:
# enter your name:RISHABH MITTAL
# enter your age:17
# where are you from:KKR
# Welcome, RISHABH MITTAL
# You are 17 years old.
# THANKS FOR VISITING MY REPO,HAVE A NICE DAY.
