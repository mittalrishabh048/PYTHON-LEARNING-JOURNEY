# %% [markdown]
# <a href="https://colab.research.google.com/github/mittalrishabh048/PYTHON-LEARNING-JOURNEY/blob/main/Week-01/Day-02-Print-Comments/print_comments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DAY 2:PRINTING SOME STATEMENTS AND UNDERSTANDING DIFFERENT TYPE OF COMMENTS

# %%
print("hello,world")
#print("hello,world)
print(45)
print(23+5)
print("harkirat","singh")
print(56-45)

#single line comment.
#multi-line comment.
'''
multi-line
comment
'''
# Out:
# hello,world
# 45
# 28
# harkirat singh
# 11
# '\nmulti-line\ncomment\n'
