# %% [markdown]
# <a href="https://colab.research.google.com/github/mittalrishabh048/PYTHON-LEARNING-JOURNEY/blob/main/Week-04/Day-28-Mini-Project/profilemanager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DAY 28:MINI-PROJECT:PROFILE MANAGER

# %%
skills_list=["python","HTML",input("Enter Skill3:")]

profile_tuple=("RahulKumar","Bangalore","Age:22")

cities_set={"New Delhi","Chandigarh",input("Another City:")}

phonebook_dict={"Home":"01712234567","Friend":input("Friend Phone:")}


print("Skills:",skills_list)
print("Profile:",profile_tuple)
print("Cities:",cities_set)
print("PhoneBook:",phonebook_dict)
# Out:
# Enter Skill3:C++
# Another City:New York
# Friend Phone:9056784325
# Skills: ['python', 'HTML', 'C++']
# Profile: ('RahulKumar', 'Bangalore', 'Age:22')
# Cities: {'New York', 'New Delhi', 'Chandigarh'}
# PhoneBook: {'Home': '01712234567', 'Friend': '9056784325'}
